# %%
import qn
import pandas as pd
from importlib.machinery import SourceFileLoader
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# import sys
# sys.path.insert(0, '.')

# %%
from src.MulSeries import MulSeries

# %%
index = pd.DataFrame([[1,2],[3,4,],[5,6]],
                     index=['a','b','c'],
                     columns=['x','y'])
name = pd.Series(['a','b'],index=['e','f'],name='cc')
ms = MulSeries([1,2,3],index=index,name=name)

# %%
ms**2
# Out:
# __pow__ <function OpsMixin.__pow__ at 0x1674fa480>
# ss:
# a    1
# b    4
# c    9
# Name: cc, dtype: int64
#
# index:
#    x  y
# a  1  2
# b  3  4
# c  5  6
#
# name:
# e    a
# f    b
# Name: cc, dtype: object

# %%
ms.__div__
# Out:
# <bound method MulSeries.__div__ of ss:
# a    1
# b    2
# c    3
# Name: cc, dtype: int64
#
# index:
#    x  y
# a  1  2
# b  3  4
# c  5  6
#
# name:
# e    a
# f    b
# Name: cc, dtype: object>

# %%
ms.__

# %%
ms.call(np.sum)
# Out:
# 6

# %%
ms.call(np.add,1).call(np.log2)
# Out:
# ss:
# a    1.000000
# b    1.584963
# c    2.000000
# Name: cc, dtype: float64
#
# index:
#    x  y
# a  1  2
# b  3  4
# c  5  6
#
# name:
# e    a
# f    b
# Name: cc, dtype: object

# %%
ms.ss.values
# Out:
# array([1, 2, 3])

# %%
np.log2(ms)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 np.log2(ms)
#
# ValueError: invalid __array_struct__

# %%
ms.mloc[{'a':['c','d']}]
# Out:
# {'a': ['c', 'd']}

# %%
ms.index.index.shape
# Out:
# (3,)

# %%
ms.mloc[:]
# Out:
# slice(None, None, None)

# %%
ms.index.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
ms.values
# Out:
# array([1, 2, 3])

# %%
ms.mname
# Out:
# e    a
# f    b
# Name: cc, dtype: object

# %%
ms.ss.iloc

# %%
ms.index.index = [5,6,7]

# %%
x = pd.Series(range(3),index=['a','b','b'])

# %%
x = {'z':'a','d':'c'}

# %%
x.keys()
# Out:
# dict_keys(['z', 'd'])

# %%
pd.Series([1,2,3]).iloc[slice(None)]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
slice(None)
# Out:
# slice(None, None, None)

# %%
x = (5,)

# %%
x
# Out:
# (5,)

# %%
list(enumerate(x))
# Out:
# [(0, 5)]

# %%
x = pd.Series([1,2,3])
y = np.log2(x)

# %%
x % 2
# Out:
# 0    1
# 1    0
# 2    1
# dtype: int64

# %%
class A:
    def __init__(self):
        self.__abc = 10
        self._bc = 5

# %%
a = A()
print(a._bc)
print(a.__abc)
# Out:
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[108], line 3
#       1 a = A()
#       2 print(a._bc)
# ----> 3 print(a.__abc)
#
# AttributeError: 'A' object has no attribute '__abc'

# %%
kk = pd.DataFrame([[],[],[]],index=[1,2,3])

# %%
class abc():
    def __init__(self,a):
        self.a = a
    def __array__(self):
        return np.array([self.a])

# %%
x = abc([1,2,3])
y = np.log2(x)

# %%
def test(func):
    print(func)
test(+)
# Out:
#   Cell In[22], line 3
#     test(+)
#           ^
# SyntaxError: invalid syntax
