# %%
import qn
import pandas as pd
from importlib.machinery import SourceFileLoader

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from MulSeries import MulSeries
MulDataFrame = SourceFileLoader("MulDataFrame",
        'MulDataFrame.py').load_module()
from MulDataFrame import MulDataFrame
# qn.reload(MulDataFrame)

# %%
index = pd.DataFrame([[1,2],[3,4],[5,6]],
                     index=['a','b','c'],
                     columns=['x','y'])
columns = pd.DataFrame([[5,7],[3,6]],
                     index=['c','d'],
                     columns=['f','g'])
md = MulDataFrame([[1,2],[3,5],[8,10]],index=index,
                  columns=columns)

# %%
md.iloc[[0]]
# Out:
# df:
#    c  d
# a  1  2
#
# index:
#    x  y
# a  1  2
#
# columns:
#    f  g
# c  5  7
# d  3  6

# %%
x = [None,1,2]

# %%
index = pd.DataFrame([[1,2],[3,4,],[5,6]],
                     index=['a','b','c'],
                     columns=['x','y'])
name = pd.Series(['a','b'],index=['e','f'],name='cc')
ms = MulSeries(pd.Series([1,2,3]),index=index,name=name)
# Out:
# True

# %%
ms.index.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
ms.values
# Out:
# array([1, 2, 3])

# %%
ms.mname
# Out:
# e    a
# f    b
# Name: cc, dtype: object

# %%
ms.ss.iloc

# %%
ms.index.index = [5,6,7]

# %%
x = pd.Series(range(3),index=['a','b','b'])

# %%
x = {'z':'a','d':'c'}

# %%
x.keys()
# Out:
# dict_keys(['z', 'd'])

# %%
pd.Series([1,2,3]).iloc[slice(None)]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
slice(None)
# Out:
# slice(None, None, None)
