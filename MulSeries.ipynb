# %%
import qn
import pandas as pd
from importlib.machinery import SourceFileLoader
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# import sys
# sys.path.insert(0, '.')

# %%
import muldataframe as md
MulSeries = md.MulSeries

# %%
import pandas as pd

# %%
import muldataframe as md
index = pd.DataFrame([[1,2],[3,6],[5,6]],
                     index=['a','b','b'],
                     columns=['x','y'])
name = pd.Series([5,7],
                        index=['f','g'],
                        name='c')
ms = MulSeries([1,8,9],index=index,name=name)

# %%
import numpy as np
ms.call(np.power,2)
# Out:
# (3,)     g  7
#          f  5
#             c
# -------  ------
#    x  y      c
# a  1  2  a   1
# b  3  6  b  64
# b  5  6  b  81

# %%
index = pd.DataFrame([[1,2],[3,5],[3,6]],
                     index=['a','b','b'],
                     columns=['x','y'])
name = pd.Series(['a','b'],index=['e','f'],name='cc')
ms = MulSeries([1,2,3],index=index,name=name)

# %%
[...]*3
# Out:
# [Ellipsis, Ellipsis, Ellipsis]

# %%
x = [..., ..., ..., 2]

# %%
x[0] is ...
# Out:
# True

# %%
ss = pd.Series([1,2],index=['a',None])

# %%
ss[None]
# Out:
# 2

# %%
ss = ms.ss
hasattr(ss,'mean')
hasattr(getattr(pd.Series,'mean'),'__call__')
# Out:
# True

# %%
hasattr(None,'abc')
# Out:
# False

# %%
hasattr(pd.Series,'std')
# Out:
# True

# %%
md.cmm.MulGroupBy
# Out:
# muldataframe.cmm.MulGroupBy

# %%
hasattr(ms,'mean')
# Out:
# True

# %%
hasattr(ms,'__add__')
# Out:
# True

# %%
ms.__add__
# Out:
# <bound method call_op_factory.<locals>.call_op of ss:
# a    1
# b    2
# b    3
# Name: cc, dtype: int64
#
# index:
#    x  y
# a  1  2
# b  3  5
# b  3  6
#
# name:
# e    a
# f    b
# Name: cc, dtype: object>

# %%
ms.__add__
# Out:
# <function muldataframe.MulSeries.MulSeries.__getattribute__.<locals>.call_op(self, other)>

# %%
ms+2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ms+2
#
# TypeError: unsupported operand type(s) for +: 'MulSeries' and 'int'

# %%
a = pd.Series([1,3],index=['a','b'])
b = pd.Series([1,3],index=['a','c'])
a+b
# Out:
# a    2.0
# b    NaN
# c    NaN
# dtype: float64

# %%
ms.ss + pd.Series([1,2,3],index=['a','c','b'])
# Out:
# a    2.0
# b    5.0
# b    6.0
# c    NaN
# dtype: float64

# %%
ms + pd.Series([1,2,3],index=['a','c','b'])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ms + pd.Series([1,2,3],index=['a','c','b'])
#
# File ~/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/MulSeries.py:203, in call_op_factory.<locals>.call_op(self, other)
#     201 func = getattr(pd.Series,op_attr)
#     202 # print(op_attr,func)
# --> 203 return self.call(func,other)
#
# File ~/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/MulSeries.py:168, in MulSeries.call(self, func, *args, **kwargs)
#     162         return MulSeries(res,
#     163                         index=self.index.copy(),
#     164                         name=name,
#     165                         index_init='override')
#     166     else:
#     167         # print('shape',res.shape,self.shape)
# --> 168         raise NotImplementedError(errMsg)
#     169 else:
#     170     return res
#
# ...

# %%
pd.Series([1,2,3],index=['a','c','b']) + ms
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 pd.Series([1,2,3],index=['a','c','b']) + ms
#
# File ~/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/MulSeries.py:203, in call_op_factory.<locals>.call_op(self, other)
#     201 func = getattr(pd.Series,op_attr)
#     202 # print(op_attr,func)
# --> 203 return self.call(func,other)
#
# File ~/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/MulSeries.py:168, in MulSeries.call(self, func, *args, **kwargs)
#     162         return MulSeries(res,
#     163                         index=self.index.copy(),
#     164                         name=name,
#     165                         index_init='override')
#     166     else:
#     167         # print('shape',res.shape,self.shape)
# --> 168         raise NotImplementedError(errMsg)
#     169 else:
#     170     return res
#
# ...

# %%
ms.index.__pandas_priority__
# Out:
# 4000

# %%
ms.ss.values
# Out:
# <capsule object NULL at 0x16b350600>

# %%
ms + pd.Series([1,2,3],index=['a','b','b'])
# Out:
# ss:
# a    2
# b    4
# b    6
# dtype: int64
#
# index:
#    x  y
# a  1  2
# b  3  5
# b  3  6
#
# name:
# Series([], dtype: object)

# %%
ms + [1,2,3]
# Out:
# ss:
# a    2
# b    4
# b    6
# Name: cc, dtype: int64
#
# index:
#    x  y
# a  1  2
# b  3  5
# b  3  6
#
# name:
# e    a
# f    b
# Name: cc, dtype: object

# %%
2*ms
# Out:
# ss:
# a    2
# b    4
# b    6
# Name: cc, dtype: int64
#
# index:
#    x  y
# a  1  2
# b  3  5
# b  3  6
#
# name:
# e    a
# f    b
# Name: cc, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ms + pd.Series([1,2,3],index=['a','c','b'])
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/arraylike.py:190, in OpsMixin.__radd__(self, other)
#     188 @unpack_zerodim_and_defer("__radd__")
#     189 def __radd__(self, other):
# --> 190     return self._arith_method(other, roperator.radd)
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/series.py:6115, in Series._arith_method(self, other, op)
#    6113 def _arith_method(self, other, op):
#    6114     self, other = self._align_for_op(other)
# ...

# %%
2+pd.Series([5,6])
# Out:
# 0    7
# 1    8
# dtype: int64

# %%
class A():
    def __init__(self,a):
        self.a = a
    
    def __add__(self,other):
        return self.a+other
a = A(6)
a + 5
5 + a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 9
#       7 a = A(6)
#       8 a + 5
# ----> 9 5 + a
#
# TypeError: unsupported operand type(s) for +: 'int' and 'A'

# %%
[1,2,3] + pd.Series([1,2,3],index=['a','b','c'])
# Out:
# a    2
# b    4
# c    6
# dtype: int64

# %%
ss = pd.Series([1,3,2],index=['b','a','c'])
ss2 = pd.Series([5,2,7],index=['c','b','a'])
ss+ss2
# Out:
# a    10
# b     3
# c     7
# dtype: int64

# %%
ss = pd.Series([1,3,2],index=['a','b','c'])
ss2 = pd.Series([5,2,7],index=['c','b','a'])
ss/ss2
# Out:
# a    0.400000
# b    1.500000
# c    0.142857
# dtype: float64

# %%
ss = pd.Series([1,3,2],index=['a','b','b'])
ss2 = pd.Series([5,2,7],index=['a','b','b'])
ss/ss2
# Out:
# a    0.142857
# b    0.600000
# b    1.500000
# b    0.400000
# b    1.000000
# dtype: float64

# %%
ss = pd.Series([1,3,2],index=['a','b','b'])
ss2 = pd.Series([5,2,7],index=['b','a','b'])
ss/ss2
# Out:
# a    0.500000
# b    0.600000
# b    0.428571
# b    0.400000
# b    0.285714
# dtype: float64

# %%
a = np.array([1,2,3])
b = a[:]
b = a.copy()
# a = [1,2,3]
# b = a[:]

# %%
b[0] = 5
print(a,b)
# Out:
# [1, 2, 3] [5, 2, 3]

# %%
ms.groupby('x',keep_primary=True,agg_mode='array').mean()
# Out:
# ss:
# 0    1.0
# 1    2.5
# Name: cc, dtype: float64
#
# index:
#   primary_index  x       y
# 0             a  1       2
# 1             b  3  [5, 6]
#
# name:
# Series([], Name: cc, dtype: object)

# %%
ms.groupby(agg_mode='array').mean()
# Out:
# ss:
# 0    1.0
# 1    2.5
# Name: cc, dtype: float64
#
# index:
#   primary_index  x       y
# 0             a  1       2
# 1             b  3  [5, 6]
#
# name:
# Series([], Name: cc, dtype: object)

# %%
df = pd.DataFrame([[1,2,3],[4,2,3],[7,8,9]],columns=['a','b','index'])

# %%
type(df.groupby(['b']).mean())
# Out:
# pandas.core.frame.DataFrame

# %%
df.reset_index()
# Out:
#    level_0  a  b  index
# 0        0  1  2      3
# 1        1  4  2      3
# 2        2  7  8      9

# %%
x = df.groupby(['b','c']).mean()

# %%
df.groupby(df.index).mean()
# Out:
#      a    b    c
# 0  1.0  2.0  3.0
# 1  4.0  2.0  3.0
# 2  7.0  8.0  9.0

# %%
ms.groupby('x').groupBy.indices
# Out:
# {1: array([0]), 3: array([1, 2])}

# %%
# Out:
# ss:
# 0    1.0
# 1    2.0
# 2    3.0
# Name: cc, dtype: float64
#
# index:
#    x  y
# 0  1  2
# 1  3  5
# 2  3  6
#
# name:
# e    a
# f    b
# Name: cc, dtype: object

# %%
list(ms.groupby('x'))
# Out:
# [(1,
#   ss:
#   a    1
#   Name: cc, dtype: int64
#
#   index:
#      x  y
#   a  1  2
#
#   name:
#   Series([], Name: cc, dtype: object)),
#  (3,
#   ss:
#   b    2
#   b    3
#   Name: cc, dtype: int64
#
#   index:
#      x  y
#   b  3  4
#   b  3  6
#
#   name:
#   Series([], Name: cc, dtype: object))]

# %%
[x for x in ms.groupby('x')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 [x for x in ms.groupby('x')]
#
# TypeError: 'type' object is not iterable

# %%
index.loc[:,[True,False]]
# Out:
#    x
# a  1
# b  3
# c  5

# %%
ms.__ss__

# %%
ms.__div__
# Out:
# <bound method MulSeries.__div__ of ss:
# a    1
# b    2
# c    3
# Name: cc, dtype: int64
#
# index:
#    x  y
# a  1  2
# b  3  4
# c  5  6
#
# name:
# e    a
# f    b
# Name: cc, dtype: object>

# %%
ms.__

# %%
ms.call(np.sum)
# Out:
# 6

# %%
ms.call(np.add,1).call(np.log2)
# Out:
# ss:
# a    1.000000
# b    1.584963
# c    2.000000
# Name: cc, dtype: float64
#
# index:
#    x  y
# a  1  2
# b  3  4
# c  5  6
#
# name:
# e    a
# f    b
# Name: cc, dtype: object

# %%
ms.ss.values
# Out:
# array([1, 2, 3])

# %%
np.log2(ms)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 np.log2(ms)
#
# ValueError: invalid __array_struct__

# %%
ms.mloc[{'a':['c','d']}]
# Out:
# {'a': ['c', 'd']}

# %%
ms.index.index.shape
# Out:
# (3,)

# %%
ms.mloc[:]
# Out:
# slice(None, None, None)

# %%
ms.index.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
ms.values
# Out:
# array([1, 2, 3])

# %%
ms.mname
# Out:
# e    a
# f    b
# Name: cc, dtype: object

# %%
ms.ss.iloc

# %%
ms.index.index = [5,6,7]

# %%
cc = pd.Series([])

# %%
cc.name

# %%
x = pd.Series([1,2,3],index=['a','b','c'],name='x')
y = pd.Series([4,5,6],index=['b','b','c'],name='y')

# %%
(x+y)
# Out:
# a    NaN
# b    6.0
# b    7.0
# c    9.0
# dtype: float64

# %%
y.name
# Out:
# 'y'

# %%
z = pd.Series(5)

# %%
z
# Out:
# 0    5
# dtype: int64

# %%
x.keys()
# Out:
# dict_keys(['z', 'd'])

# %%
pd.Series([1,2,3]).iloc[slice(None)]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
slice(None)
# Out:
# slice(None, None, None)

# %%
x = (5,)

# %%
x
# Out:
# (5,)

# %%
list(enumerate(x))
# Out:
# [(0, 5)]

# %%
x = pd.Series([1,2,3])
y = np.log2(x)

# %%
x % 2
# Out:
# 0    1
# 1    0
# 2    1
# dtype: int64

# %%
class A:
    def __init__(self):
        self.__abc = 10
        self._bc = 5

# %%
a = A()
print(a._bc)
print(a.__abc)
# Out:
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[108], line 3
#       1 a = A()
#       2 print(a._bc)
# ----> 3 print(a.__abc)
#
# AttributeError: 'A' object has no attribute '__abc'

# %%
kk = pd.DataFrame([[],[],[]],index=[1,2,3])

# %%
class abc():
    def __init__(self,a):
        self.a = a
    def __iter__(self):
        for i in range(3):
            yield i
    # def __array__(self):
    #     return np.array([self.a])

# %%
x = abc(5)

# %%
for i in x:
    print(i)
# Out:
# 0
# 1
# 2

# %%
x = abc([1,2,3])
y = np.log2(x)

# %%
def test(func):
    print(func)
test(+)
# Out:
#   Cell In[22], line 3
#     test(+)
#           ^
# SyntaxError: invalid syntax

# %%
x = pd.Series([1,2],name='a')
y = pd.Series([3,4],name='b')
pd.concat([x,y],join='inner')
# Out:
# 0    1
# 1    2
# 0    3
# 1    4
# dtype: int64

# %%
x = pd.DataFrame([[1,2,3]],columns=['a','b','c'])
y = pd.DataFrame([[1,3]],columns=['c','a'])
pd.concat([x,y],join='inner')
# Out:
#    a    b  c
# 0  1  2.0  3
# 0  3  NaN  1

# %%
getattr(np,'sum')
# Out:
# <function sum at 0x1112ba170>

# %%
index = pd.DataFrame([['a','b'],['c','d'],
                          ['e','f']],
                         index=['a','b','b'])
ms = MulSeries(pd.Series([1,3,5],
                    index=['a','b','b']), 
                        index=index)

# %%
x = pd.Series([1,2])
y = pd.Series([5,6])
pd.concat([x,y])
# Out:
# 0    1
# 1    2
# 0    5
# 1    6
# dtype: int64

# %%
slice(None) == slice(None,None,None)
# Out:
# True

# %%
x = pd.Series([1,2,3])
getattr(x,'iloc')[slice(None)]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
x.iloc[[0,1]] = [5,6]
print(x)
x.iloc[:] = [5,6,7]
x
# Out:
# 0    5
# 1    6
# 2    3
# dtype: int64
# 0    5
# 1    6
# 2    7
# dtype: int64

# %%
x.iloc[[True,False,True]]
# Out:
# 0    5
# 2    7
# dtype: int64
