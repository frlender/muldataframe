# %%
import qn
qn.config(globals())

# %%
df = pd.DataFrame([[1,2],[3,4],[5,6]],index=['a','b','b'])

# %%
indexf = pd.DataFrame([['a','b'],['a','f'],['c','f']],
                     columns=['x','y'])

# %%
index = pd.MultiIndex.from_frame(indexf)
cols = pd.MultiIndex.from_frame(indexf.transpose())

# %%
idx = pd.IndexSlice

# %%
df2 = pd.DataFrame(df.values,
                   index=index)

# %%
df2 = pd.DataFrame(df.values,
                   index=index,
                   columns=cols)

# %%
df2.loc[idx[['a','a'],['f','b']],:]
# Out:
#      0  1
# x y
# a f  3  4
#   b  1  2

# %%
df2.loc[idx['c','f'],:] # shape (2,)
# Out:
# 0    5
# 1    6
# Name: (c, f), dtype: int64

# %%
df2.loc[idx['a','f'],:] # shape (2,)
# Out:
# 0    3
# 1    4
# Name: (a, f), dtype: int64

# %%
df2.loc[idx['a',['f','f']],:] # shape (1,2)
# Out:
#      0  1
# x y
# a f  3  4

# %%
df2.loc[idx['c'],:] # shape (1,2)
# Out:
#    0  1
# y
# f  5  6

# %%
df2
# Out:
#      0  1
# x y
# a b  1  2
#   f  3  4
# c f  5  6

# %%
fk = pd.Series([1,2,3,5],['f','b','f','b'])

# %%
fk[['b','f']]
# Out:
# b    2
# b    5
# f    1
# f    3
# dtype: int64

# %%
fk[['b','b']]
# Out:
# b    2
# b    5
# b    2
# b    5
# dtype: int64

# %%
class A:
    def __init__(self, x):
        self.x = x

    def f(self):
        return self.x

class B(A):
    def f(self):
        return self.x*2

b = B(3)
b.f()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 15
#      12     def f(self):
#      13         return self.x*2
# ---> 15 b = B(3)
#      16 b.f()
#
# Cell In[10], line 10, in B.__init__(self, x)
#       9 def __init__(self, x):
# ---> 10     super().__init__(x)
#
# TypeError: object.__init__() takes exactly one argument (the instance to initialize)
