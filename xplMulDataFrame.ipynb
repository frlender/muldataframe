# %%
import qn
qn.config(globals())

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import muldataframe as md
MulDataFrame = md.MulDataFrame

# %%
index = pd.DataFrame([[1,2,'d'],
                          [3,6,'d'],
                          [5,6,'e']],
                     index=['a','b','b'],
                     columns=['x','y','y'])
columns = pd.DataFrame([[5,7],[3,6]],
                    index=['c','d'],
                    columns=['f','g'])
mf = MulDataFrame([[1,2],[8,9],[8,10]],
    index=index,columns=columns)

# %%
print(mf.loc['b'])
# Out:
# (2, 2)      g  7  6
#             f  5  3
#                c  d
# ----------  ---------
#    x  y  y     c   d
# b  3  6  d  b  8   9
# b  5  6  e  b  8  10

# %%
index = pd.DataFrame([[1,2],[3,6],[5,6]],
                     index=['a','b','b'],
                     columns=['x','y'])
columns = pd.DataFrame([[5,7],[3,6]],
                     index=['c','d'],
                     columns=['f','g'])
md = MulDataFrame([[1,2],[8,9],[8,7]],index=index,
                  columns=columns)
mf = md

# %%
mf.mloc[[[1],[2,6]]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 mf.mloc[[[1],[2,6]]]
#
# File ~/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/cmm.py:31, in Accessor.__getitem__(self, key)
#      29 if isinstance(key,tuple) and len(key) > self.max_idx:
#      30     raise IndexError(f"Too many indices. Only {self.max_idx} {'indices are' if self.max_idx > 1 else 'index is'} allowed")
# ---> 31 return self.getter(key)
#
# File ~/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/MulDataFrame.py:503, in MulDataFrame._mloc_get(self, key)
#     502 def _mloc_get(self,key):
# --> 503     nx_idx, nx_col = self._mloc2pos(key)
#     504     return self.iloc[nx_idx,nx_col]
#
# File ~/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/MulDataFrame.py:495, in MulDataFrame._mloc2pos(self, key)
#     493     nx_idx = idx
#     494 else:
# --> 495     nx_idx = cmm._mloc_idx(idx,self.mindex)
#     496 if col == slice(None):
#     497     nx_col = col
#
# File ~/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/cmm.py:72, in _mloc_idx(key, df)
#      70             ss.index = list(range(df.shape[0]))
#      71             col_nx = ss.loc[nx]
# ---> 72             nx = _mloc_idx_each(nx,col_nx,idx)
#      73 else:
#      74     for k, idx in key.items():
#
# File ~/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/cmm.py:45, in _mloc_idx_each(nx, col_nx, idx)
#      42 if isinstance(col_nx,pd.Series):
#      43     col_nx_reverse = pd.Series(col_nx.index.values,
#      44                                index=col_nx.values)
# ---> 45     col_idx = col_nx_reverse.loc[idx]
#      46     return col_idx.values if isinstance(col_idx,pd.Series) \
#      47           else col_idx
#      48 else:
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/indexing.py:1421, in _LocIndexer._getitem_axis(self, key, axis)
#    1418     if hasattr(key, "ndim") and key.ndim > 1:
#    1419         raise ValueError("Cannot index with multidimensional key")
# -> 1421     return self._getitem_iterable(key, axis=axis)
#    1423 # nested tuple slicing
#    1424 if is_nested_tuple(key, labels):
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/indexing.py:1361, in _LocIndexer._getitem_iterable(self, key, axis)
#    1358 self._validate_key(key, axis)
#    1360 # A collection of keys
# -> 1361 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1362 return self.obj._reindex_with_indexers(
#    1363     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1364 )
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/indexing.py:1559, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1556 ax = self.obj._get_axis(axis)
#    1557 axis_name = self.obj._get_axis_name(axis)
# -> 1559 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1561 return keyarr, indexer
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6199 self._raise_if_missing(keyarr, indexer, axis_name)
#    6201 keyarr = self.take(indexer)
#    6202 if isinstance(key, Index):
#    6203     # GH 42790 - Preserve name from an Index
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6251, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6248     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6251 raise KeyError(f"{not_found} not in index")
#
# KeyError: '[6] not in index'

# %%
print(mf.mloc[{'y':[2,6],'x':3}])
# Out:
# (2,)     y  6
#          x  3
#             b
# -------  ------
#    f  g     b
# c  5  7  c  8
# d  3  6  d  9

# %%
mf.mloc[[3,6]]
# Out:
# (2,)     y  6
#          x  3
#             b
# -------  ------
#    f  g     b
# c  5  7  c  8
# d  3  6  d  9

# %%
print(mf.mloc[[..., 6],[3]])
# Out:
# (2,)     g  6
#          f  3
#             d
# -------  ------
#    x  y     d
# b  3  6  b  9
# b  5  6  b  7

# %%
mf2 = mf.copy()
mf2.index.index = ['d','e',5]
mf2.df
# Out:
#    c  d
# d  1  2
# e  8  9
# 5  8  7

# %%
print(md.mindex)
# Out:
#    x  y
# a  1  2
# b  3  6
# b  5  6

# %%
print(md.loc['b'])
# Out:
# (2, 2)    g  7  6
#           f  5  3
#              c  d
# --------  ---------
#    x  y      c  d
# b  3  6   b  8  9
# b  5  6   b  8  7

# %%
type(np.array([1,2,3]))
# Out:
# numpy.ndarray

# %%
isinstance(slice(None),slice)
# Out:
# True

# %%
isinstance(np.array([1,2,3]),np.ndarray)
# Out:
# True

# %%
df = md.df
df
# Out:
#    c  d
# a  1  2
# b  8  9
# b  8  7

# %%
ss = df.iloc[:,0]
ss[ss>1]
# Out:
# b    8
# b    8
# Name: c, dtype: int64

# %%
ss.loc[ss>1]
# Out:
# b    8
# b    8
# Name: c, dtype: int64

# %%
df[[True,False,True]]
# Out:
#    c  d
# a  1  2
# b  8  7

# %%
df[df['c'] > 1]
# Out:
#    c  d
# b  8  9
# b  8  7

# %%
df.loc[:,df.loc['a']>1]
# Out:
#    d
# a  2
# b  9
# b  7

# %%
print(md.insert('e',[7,8,9],inplace=False))
# Out:
# (3, 3)    g  7  6  None
#           f  5  3  None
#              c  d     e
# --------  ---------------
#    x  y      c  d  e
# a  1  2   a  1  2  7
# b  3  6   b  8  9  8
# b  5  6   b  8  7  9

# %%
eq([None],[np.nan])
[np.nan]*3
# Out:
# [nan, nan, nan]

# %%
x = slice(None)
x == slice(None)
# Out:
# True

# %%
df = md.df

# %%
df.loc['g'] = [None]*2

# %%
df2 = df.transpose()
del df2['b']

# %%
ss = df.iloc[:,0]
del ss['b']
ss
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 ss = df.iloc[:,0]
# ----> 2 del ss['b']
#       3 ss
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/generic.py:4501, in NDFrame.__delitem__(self, key)
#    4496 if not deleted:
#    4497     # If the above loop ran and didn't delete anything because
#    4498     # there was no match, this call should raise the appropriate
#    4499     # exception:
#    4500     loc = self.axes[-1].get_loc(key)
# -> 4501     self._mgr = self._mgr.idelete(loc)
#    4503 # delete from the caches
#    4504 try:
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/internals/managers.py:2051, in SingleBlockManager.idelete(self, indexer)
#    2045 def idelete(self, indexer) -> SingleBlockManager:
#    2046     """
#    2047     Delete single location from SingleBlockManager.
#    2048
#    2049     Ensures that self.blocks doesn't become empty.
#    2050     """
# -> 2051     nb = self._block.delete(indexer)[0]
#    2052     self.blocks = (nb,)
#    2053     self.axes[0] = self.axes[0].delete(indexer)
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:1940, in Block.delete(self, loc)
#    1938 if self.ndim == 1:
#    1939     values = cast(np.ndarray, self.values)
# -> 1940     values = np.delete(values, loc)
#    1941     mgr_locs = self._mgr_locs.delete(loc)
#    1942     return [type(self)(values, placement=mgr_locs, ndim=self.ndim)]
#
# File ~/miniforge3/lib/python3.11/site-packages/numpy/lib/function_base.py:5353, in delete(arr, obj, axis)
#    5351 else:
#    5352     keep = ones(N, dtype=bool)
# -> 5353     keep[obj,] = False
#    5355 slobj[axis] = keep
#    5356 new = arr[tuple(slobj)]
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
df.insert(2,'e',[None]*3)
df
# Out:
# pp  c  d     e
# a   1  2  None
# b   8  9  None
# b   8  7  None

# %%
# df.index.name = 'kk'
df.columns.name = 'pp'
print(df)
# Out:
# pp  c  d
# a   1  2
# b   8  9
# b   8  7

# %%
ss = df.iloc[:,0]

# %%
ss.loc['c'] = 5

# %%
df.loc['e'] = (5,6)

# %%
df
# Out:
#    c  d
# a  1  2
# b  8  9
# b  8  7
# d  5  6
# e  5  6

# %%
print(md>5)
# Out:
# (3, 2)    g  7  6
#           f  5  3
#              c  d
# --------  ---------------
#    x  y          c      d
# a  1  2   a  False  False
# b  3  6   b   True   True
# b  5  6   b   True   True
# /Users/qn/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/ValFrameBase.py:10: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self.parent = parent

# %%
cc = md > 5
print(cc)
# Out:
# (3, 2)    g  7  6
#           f  5  3
#              c  d
# --------  ---------------
#    x  y          c      d
# a  1  2   a  False  False
# b  3  6   b   True   True
# b  5  6   b   True   True
# /Users/qn/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/ValFrameBase.py:10: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   self.parent = parent

# %%
md+2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 md+2
#
# TypeError: unsupported operand type(s) for +: 'MulDataFrame' and 'int'

# %%
import tabulate
tabulate.PRESERVE_WHITESPACE = True

# %%
str(index)
# Out:
# '   x  y\na  1  2\nb  3  6\nb  5  6'

# %%
def tx(x):
    xs = str(x.transpose())
    lines = xs.split('\n')
    lines = lines[1:]+[lines[0]]
    return '\n'.join(lines)

# %%
print(tabulate.tabulate([[str(index),str(md.df)]],
               headers=['(3,2)',str(tx(columns))]))
# Out:
# (3,2)    f  5  3
#          g  7  6
#             c  d
# -------  ---------
#    x  y     c   d
# a  1  2  a  1   2
# b  3  6  b  8   9
# b  5  6  b  8  10

# %%
ss = pd.Series([1,2,3])
ds = pd.DataFrame(ss)
ds.columns = [None]
ds
# Out:
#    None
# 0     1
# 1     2
# 2     3

# %%
print(str(ss))
# Out:
# 0    1
# 1    2
# 2    3
# Name: 5, dtype: int64

# %%
str(md.df)
# Out:
# '   c   d\na  1   2\nb  8   9\nb  8  10'

# %%
cc = pd.DataFrame(columns=['a','b'])
cc.shape
# Out:
# (0, 2)

# %%
ck = pd.DataFrame(index=cc.index)
ck.shape
# Out:
# (0, 0)

# %%
str(cc)
# Out:
# 'Empty DataFrame\nColumns: [a, b]\nIndex: []'

# %%
print(tx(columns))
# Out:
# f  5  3
# g  7  6
#    c  d

# %%
print(tabulate.tabulate([['  a','  b']],
               headers=[' k',' f'],
               tablefmt='simple'))
# Out:
#  k     f
# ----  ----
#   a     b

# %%
str(index).replace(' ','@')
# Out:
# '@@@x@@y\na@@1@@2\nb@@3@@6\nb@@5@@6'

# %%
print(tabulate.tabulate([['a','e'],['b','x']],
               headers=['c','d']))
# Out:
# c    d
# ---  ---
# a    e
# b    x

# %%
print(str(index))
# Out:
#    x  y
# a  1  2
# b  3  6
# b  5  6

# %%
df = md.df

# %%
df.insert

# %%
df.insert(0,None,5,allow_duplicates=True)

# %%
ss = df['c']

# %%
df.index.name

# %%
ss = df['c']
ss.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 ss = df['c']
# ----> 2 ss.reset_index(inplace=True)
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/series.py:1747, in Series.reset_index(self, level, drop, name, inplace, allow_duplicates)
#    1743         return self._constructor(
#    1744             self._values.copy(), index=new_index, copy=False, dtype=self.dtype
#    1745         ).__finalize__(self, method="reset_index")
#    1746 elif inplace:
# -> 1747     raise TypeError(
#    1748         "Cannot reset_index inplace on a Series to create a DataFrame"
#    1749     )
#    1750 else:
#    1751     if name is lib.no_default:
#    1752         # For backwards compatibility, keep columns as [0] instead of
#    1753         #  [None] when self.name is None
#
# TypeError: Cannot reset_index inplace on a Series to create a DataFrame

# %%
pd.DataFrame(df.index)
# Out:
#    0
# 0  a
# 1  b
# 2  b

# %%
pd.DataFrame(ss).transpose()
# Out:
#    a  b  b
# c  1  8  8

# %%
df.insert(0,'b',5,allow_duplicates=True)

# %%
df
# Out:
#    b  b  a  c   d
# a  5  5  1  1   2
# b  5  5  2  8   9
# b  5  5  3  8  10

# %%
x = np.array([[1,2],[5,6]])
y = x.copy().T
x[0,0] = 5

# %%
y
# Out:
# array([[1, 5],
#        [2, 6]])

# %%
df = md.df

# %%
list(df.transpose().groupby(df.index,axis=1))
# Out:
# /var/folders/fh/dw4ym82j08l67xt8ndms1f_c0000gn/T/ipykernel_28043/667695596.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   list(df.transpose().groupby(df.index,axis=1))
# [('a',
#      a
#   c  1
#   d  2),
#  ('b',
#      b   b
#   c  8   8
#   d  9  10)]

# %%
df.groupby(df.index).mean()
# Out:
#      c    d
# a  1.0  2.0
# b  8.0  9.5

# %%
df.transpose().groupby(df.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df.transpose().groupby(df.index).mean(axis=1)
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/frame.py:9156, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9153 if level is None and by is None:
#    9154     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9156 return DataFrameGroupBy(
#    9157     obj=self,
#    9158     keys=by,
#    9159     axis=axis,
#    9160     level=level,
#    9161     as_index=as_index,
#    9162     sort=sort,
#    9163     group_keys=group_keys,
#    9164     observed=observed,
#    9165     dropna=dropna,
#    9166 )
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:1054, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1049         in_axis = False
#    1051     # create the Grouping
#    1052     # allow us to passing the actual Grouping as the gpr
#    1053     ping = (
# -> 1054         Grouping(
#    1055             group_axis,
#    1056             gpr,
#    1057             obj=obj,
#    1058             level=level,
#    1059             sort=sort,
#    1060             observed=observed,
#    1061             in_axis=in_axis,
#    1062             dropna=dropna,
#    1063         )
#    1064         if not isinstance(gpr, Grouping)
#    1065         else gpr
#    1066     )
#    1068     groupings.append(ping)
#    1070 if len(groupings) == 0 and len(obj):
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:541, in Grouping.__init__(self, index, grouper, obj, level, sort, observed, in_axis, dropna, uniques)
#     539 self.level = level
#     540 self._orig_grouper = grouper
# --> 541 grouping_vector = _convert_grouper(index, grouper)
#     542 self._all_grouper = None
#     543 self._orig_cats = None
#
# File ~/miniforge3/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:1096, in _convert_grouper(axis, grouper)
#    1094 elif isinstance(grouper, (list, tuple, Index, Categorical, np.ndarray)):
#    1095     if len(grouper) != len(axis):
# -> 1096         raise ValueError("Grouper and axis must be same length")
#    1098     if isinstance(grouper, (list, tuple)):
#    1099         grouper = com.asarray_tuplesafe(grouper)
#
# ValueError: Grouper and axis must be same length

# %%
md.df.mean(axis=1)
# Out:
# a    1.5
# b    8.5
# b    9.0
# dtype: float64

# %%
pd.DataFrame(md.df.iloc[:2])
# Out:
#    c  d
# a  1  2
# b  8  9

# %%
md.__df = [1,2]
md.__df
# Out:
# [1, 2]

# %%
md * pd.Series([2,2],index=['d','c'])
# Out:
# df:
#     c   d
# a   2   4
# b  16  18
# b  16  20
#
# index:
#    x  y
# a  1  2
# b  3  6
# b  5  6
#
# columns:
#    f  g
# c  5  7
# d  3  6

# %%
md + pd.DataFrame([[1,1],[1,1],[1,1]],index=['a','b','b'],
                  columns=['c','d'])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 md + pd.DataFrame([[1,1],[1,1],[1,1]],index=['a','b','b'],
#       2                   )
#
# File ~/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/MulDataFrame.py:444, in call_op_factory.<locals>.call_op(self, other)
#     442 func = getattr(pd.DataFrame,op_attr)
#     443 # print(op_attr,func)
# --> 444 return self.call(func,other)
#
# File ~/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/MulDataFrame.py:297, in MulDataFrame.call(self, func, *args, **kwargs)
#     294 if isinstance(new_df,pd.DataFrame):
#     295     if new_df.shape[0] != self.shape[0] or \
#     296         new_df.shape[1] != self.shape[1]:
# --> 297         raise NotImplementedError
#     299     new_mindex = cmm.align_index_in_call(new_df.index,self,'index')
#     300     new_mcols = cmm.align_index_in_call(new_df.columns,self,'columns')
#
# NotImplementedError:

# %%
md
# Out:
# df:
#    c   d
# a  1   2
# b  8   9
# b  8  10
#
# index:
#    x  y
# a  1  2
# b  3  6
# b  5  6
#
# columns:
#    f  g
# c  5  7
# d  3  6

# %%
import inspect
hasattr(np.mean,'__call__')

# type(np.mean) == types.MethodType
# Out:
# True

# %%
md.iloc[:,0]
# Out:
# ss:
# a    1
# b    8
# b    8
# Name: c, dtype: int64
#
# index:
#    x  y
# a  1  2
# b  3  6
# b  5  6
#
# name:
# f    5
# g    7
# Name: c, dtype: int64

# %%
len(md.df.iloc[0])
# Out:
# 2

# %%
df = md.df

# %%
df.index.name = 'xx'

# %%
lf = df.melt(value_vars=['c','d'],ignore_index=False)

# %%
lf
# Out:
#    variable  value
# xx
# a         c      1
# b         c      8
# b         c      8
# a         d      2
# b         d      9
# b         d     10

# %%
x = True
x is True
# Out:
# True

# %%
x = 5
hasattr(md,'__pandas_priority__')
# Out:
# True

# %%
x = np.array([[1,2],[3,4],[5,6]])
np.ravel(x)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
def abc(x=None,y=None,**kwargs):
    print(x,y,kwargs)

# %%
abc(5,c=3)
# Out:
# 5 None {'c': 3}

# %%
df.query('index == "b"')
# Out:
#    c   d
# b  8   9
# b  8  10

# %%
md.set_index('c',drop=True)
# Out:
# df:
#     d
# a   2
# b   9
# b  10
#
# index:
#    x  y  c
# a  1  2  1
# b  3  6  8
# b  5  6  8
#
# columns:
#    f  g
# d  3  6

# %%
df = md.df

# %%
df.drop_duplicates('c')
# Out:
#    c  d
# a  1  2
# b  8  9

# %%
md.drop_duplicates(['c'])
# Out:
# df:
#    c  d
# a  1  2
# b  8  9
#
# index:
#    x  y
# a  1  2
# b  3  6
#
# columns:
#    f  g
# c  5  7
# d  3  6

# %%
md.loc['b']
# Out:
# df:
#    c   d
# b  8   9
# b  8  10
#
# index:
#    x  y
# b  3  6
# b  5  6
#
# columns:
#    f  g
# c  5  7
# d  3  6

# %%
class A():
    def __init__(self, x):
        self.x = x
        
    def f(self):
        print(self.x)

class B(A):
    def __init__(self, x):
        super().__init__(x)
    def f(self):
        print(self.x*2)

# %%
x = pd.Series([1,2,2])
x.loc[~x.duplicated()]
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
df.values[[False,True,False]]
# Out:
# array([[8, 9]])

# %%
x = pd.Series([1,2,3],index=['a','b','b'])

# %%
x.shape
# Out:
# 1

# %%
pd.concat([df,x],axis=1)
# Out:
#    c   d  0
# a  1   2  1
# b  8   9  2
# b  8  10  3

# %%
x.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
b = B(3)
b.f()
super(B,b).f()
# Out:
# 6
# 3

# %%
class LittleMeta(type):
    def __new__(cls, clsname, superclasses, attributedict):
        print("clsname: ", clsname)
        print("superclasses: ", superclasses)
        print("attributedict: ", attributedict)
        return type.__new__(cls, clsname, superclasses, attributedict)
    def __init__(cls, clsname, superclasses, attributedict):
        print("init clsname: ", clsname)
        print("init superclasses: ", superclasses)
        print("init attributedict: ", attributedict)
        return type.__init__(cls, clsname, superclasses, attributedict)
    def abc(self):
        return "abc"

# %%
from abc import ABC,abstractmethod

class A(ABC):
    def __init__(self, x):
        self.x = x
    
    @classmethod
    def f(self):
        return self.x + 1
    
    @abstractmethod
    def f2(self):
        return self.x + 1
    
    def f3(self):
        return self.x + 1

# %%
k = A(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 k = A(5)
#
# TypeError: Can't instantiate abstract class A with abstract method f2

# %%
dict(A.__dict__)
# Out:
# {'__module__': '__main__',
#  '__init__': <function __main__.A.__init__(self, x)>,
#  'f': <classmethod(<function A.f at 0x16aee9c60>)>,
#  'f2': <function __main__.A.f2(self)>,
#  'f3': <function __main__.A.f3(self)>,
#  '__dict__': <attribute '__dict__' of 'A' objects>,
#  '__weakref__': <attribute '__weakref__' of 'A' objects>,
#  '__doc__': None,
#  '__abstractmethods__': frozenset({'f2'}),
#  '_abc_impl': <_abc._abc_data at 0x16aefbdc0>}

# %%
abc = type('abc',(ABC,),dict(A.__dict__))

# %%
abc(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 abc(5)
#
# TypeError: Can't instantiate abstract class abc with abstract method f2

# %%
class A(pd.DataFrame,metaclass=LittleMeta):
    def f(self):
        print('a')
# Out:
# clsname:  A
# superclasses:  (<class 'pandas.core.frame.DataFrame'>,)
# attributedict:  {'__module__': '__main__', '__qualname__': 'A', 'f': <function A.f at 0x16b63ae80>}
# init clsname:  A
# init superclasses:  (<class 'pandas.core.frame.DataFrame'>,)
# init attributedict:  {'__module__': '__main__', '__qualname__': 'A', 'f': <function A.f at 0x16b63ae80>}

# %%
class A:
    pass

# %%
index = pd.DataFrame([[1,2],[3,6],[5,6]],
                     index=['a','b','b'],
                     columns=['x','y'])
df =pd.DataFrame([[1,2],[8,9],[8,10]],index=pd.MultiIndex.from_frame(index))

# %%
for k, row in df.iterrows():
    print(k,row)
# Out:
# (1, 2) 0    1
# 1    2
# Name: (1, 2), dtype: int64
# (3, 6) 0    8
# 1    9
# Name: (3, 6), dtype: int64
# (5, 6) 0     8
# 1    10
# Name: (5, 6), dtype: int64

# %%
xf = pd.DataFrame([[1,2],[3,4],[5,6]],index=['a','b','b'])

# %%
xf.groupby()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/fh/dw4ym82j08l67xt8ndms1f_c0000gn/T/ipykernel_98897/2721402265.py in ?()
# ----> 1 xf.groupby()
#
# ~/miniforge3/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9150
#    9151         from pandas.core.groupby.generic import DataFrameGroupBy
#    9152
#    9153         if level is None and by is None:
# -> 9154             raise TypeError("You have to supply one of 'by' and 'level'")
#    9155
#    9156         return DataFrameGroupBy(
#    9157             obj=self,
#
# TypeError: You have to supply one of 'by' and 'level'

# %%
row
# Out:
# 0     8
# 1    10
# Name: (5, 6), dtype: int64

# %%
def fa():
    pass
fa.__name__
# Out:
# 'fa'

# %%
df = md.df
df.index = pd.MultiIndex.from_frame(index)
df.columns = pd.MultiIndex.from_frame(columns)

# %%
df
# Out:
# f    5   3
# g    7   6
# x y
# 1 2  1   2
# 3 6  8   9
# 5 6  8  10

# %%
df.index.to_frame(index=False)
# Out:
#    x  y
# 0  1  2
# 1  3  6
# 2  5  6

# %%
vals = df.values
vals[0,0]
# Out:
# 1

# %%
df
# Out:
# [autoreload of muldataframe.util failed: Traceback (most recent call last):
#   File "/Users/qn/miniforge3/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/qn/miniforge3/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/Users/qn/miniforge3/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/Users/qn/Documents/NuMedii_mac/Jandas/muldataframe/muldataframe/util.py", line 47
#     pass
#     ^^^^
# IndentationError: expected an indented block after 'if' statement on line 45
# ]
#     c   d
# xx
# a   1   2
# b   8   9
# b   8  10

# %%
x = md.__class__.__name__

# %%
md.xx
